# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(.1,10,.1)
y=np.sqrt(x)
plt.title('Unimodal')
plt.xlabel('Proportion of trials probe is seen "left"')
plt.ylabel('Displacement of probe (degs)')
plt.plot(x)
plt.show()
